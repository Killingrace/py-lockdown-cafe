# %%
for i, j in enumerate(("a", "b", "c")):
    print(i, j)
# Out:
# 0 a
# 1 b
# 2 c

# %%
from datetime import date

visitor = {
    "name": "Paul",
    "age": 23,
    "vaccine": {
        "expiration_date": date.today()
    },
    "wearing_a_mask": False
}
if not visitor.get("wearing_a_mask"):
    print("us")
# Out:
# us

# %%
from datetime import date

date(year=2019, month=2, day=23) > date.today()
# Out:
# False
